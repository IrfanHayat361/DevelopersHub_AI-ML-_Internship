# %% [markdown]
# # Short-Term Stock Price Prediction using Machine Learning
#
# This project predicts the next day's closing stock price using historical market data.
# We use Open, High, Low, and Volume as features and train a regression model to estimate the next Close price.
#
# **Stock Selected:** Apple Inc.
# **Model Used:** Linear Regression
# **Data Source:** Yahoo Finance (via yfinance API)

# %% [markdown]
# ## Problem Statement
#
# Stock markets generate large volumes of time-series data every day.
# The goal of this project is to:
#
# - Fetch historical stock data
# - Engineer features for prediction
# - Train a regression model
# - Predict the next day’s closing price
# - Compare predicted vs actual prices visually
#
# This is a **short-term regression problem**, not long-term forecasting.

# %%
pip install yfinance pandas numpy matplotlib scikit-learn
# Out:
# Collecting yfinance
#   Downloading yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas in d:\ai\envs\ml\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in d:\ai\envs\ml\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in d:\ai\envs\ml\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in d:\ai\envs\ml\lib\site-packages (1.7.2)
# Requirement already satisfied: requests>=2.31 in d:\ai\envs\ml\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in d:\ai\envs\ml\lib\site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in d:\ai\envs\ml\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-cp310-cp310-win_amd64.whl.metadata (24 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.18.3.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#      ---------- ----------------------------- 0.8/3.0 MB 2.0 MB/s eta 0:00:02
#      ------------- -------------------------- 1.0/3.0 MB 1.9 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.3/3.0 MB 1.7 MB/s eta 0:00:02
#      ------------------------ --------------- 1.8/3.0 MB 1.8 MB/s eta 0:00:01
#      --------------------------- ------------ 2.1/3.0 MB 1.8 MB/s eta 0:00:01
#      ------------------------------- -------- 2.4/3.0 MB 1.8 MB/s eta 0:00:01
#      -------------------------------------- - 2.9/3.0 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 1.7 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\ai\envs\ml\lib\site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cffi>=1.12.0 in d:\ai\envs\ml\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in d:\ai\envs\ml\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\ai\envs\ml\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\ai\envs\ml\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\ai\envs\ml\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: scipy>=1.8.0 in d:\ai\envs\ml\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\ai\envs\ml\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\ai\envs\ml\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\ai\envs\ml\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\ai\envs\ml\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in d:\ai\envs\ml\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in d:\ai\envs\ml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\ai\envs\ml\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\ai\envs\ml\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ai\envs\ml\lib\site-packages (from requests>=2.31->yfinance) (2.6.2)
# Downloading yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.3 MB/s  0:00:01
# Downloading frozendict-2.4.7-cp310-cp310-win_amd64.whl (37 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Building wheels for collected packages: multitasking, peewee
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=34d97abe497a64179f80ab2a67497b61aebe69b7ccfc76b025e04edb82432105
#   Stored in directory: c:\users\irfan hayat\appdata\local\pip\cache\wheels\e9\25\85\25d2e1cfc0ece64b930b16972f7e4cc3599c43b531f1eba06d
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.18.3-py3-none-any.whl size=139181 sha256=edacc8f4c6fb16582838170b2551a938f8666b3a663f92f40b57da9e0877ad82
#   Stored in directory: c:\users\irfan hayat\appdata\local\pip\cache\wheels\3d\96\39\80c50cbf6bd446cdca9dac7d78a1a0d3a1f313859500529f8d
# Successfully built multitasking peewee
# Installing collected packages: peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ---------------------- ----------------- 4/7 [frozendict]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------------- 7/7 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-3.18.3 protobuf-6.33.2 websockets-15.0.1 yfinance-1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Required Libraries
#
# We import:
# - Data handling libraries
# - Visualization tools
# - Machine learning utilities
# - Yahoo Finance API wrapper

# %%
import yfinance as yf
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ## Fetching Historical Stock Data
#
# We use the yfinance library to retrieve historical stock data directly from Yahoo Finance.
#
# The dataset includes:
# - Open
# - High
# - Low
# - Close
# - Volume
#
# We download data for the selected stock over multiple years to ensure sufficient training samples.

# %%
# Select stock ticker
ticker = "AAPL"

# Download last 5 years of data
data = yf.download(ticker, period="5y")

# Display first few rows
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-12-28  133.061203  133.693941  129.965617  130.432885  124486200
# 2020-12-29  131.289505  135.105436  130.773576  134.385091  121047300
# 2020-12-30  130.170059  132.379800  129.858547  131.980681   96452100
# 2020-12-31  129.167404  131.162985  128.223154  130.520502   99116600
# 2021-01-04  125.974442  130.062937  123.394792  129.975330  143301900

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Before training the model, we:
# - Inspect the dataset structure
# - Check for missing values
# - Understand feature distributions
#
# This step ensures the data is clean and suitable for modeling.

# %%
# Select relevant features
data = data[['Open', 'High', 'Low', 'Volume', 'Close']]

# Drop missing values
data.dropna(inplace=True)

data.head()
# Out:
# Price             Open        High         Low     Volume       Close
# Ticker            AAPL        AAPL        AAPL       AAPL        AAPL
# Date
# 2020-12-28  130.432885  133.693941  129.965617  124486200  133.061203
# 2020-12-29  134.385091  135.105436  130.773576  121047300  131.289505
# 2020-12-30  131.980681  132.379800  129.858547   96452100  130.170059
# 2020-12-31  130.520502  131.162985  128.223154   99116600  129.167404
# 2021-01-04  129.975330  130.062937  123.394792  143301900  125.974442

# %% [markdown]
# ## Feature Engineering
#
# To predict the next day’s Close price, we:
#
# - Use today's Open, High, Low, and Volume as input features
# - Shift the Close price by **-1 day** to create the target variable
#
# This transforms the time-series data into a supervised learning problem.

# %%
# Shift Close price upward to predict next day's Close
data['Target_Close'] = data['Close'].shift(-1)
# Drop last row (it has no future value)
data.dropna(inplace=True)

data.head()
# Out:
# Price             Open        High         Low     Volume       Close  \
# Ticker            AAPL        AAPL        AAPL       AAPL        AAPL
# Date
# 2020-12-28  130.432885  133.693941  129.965617  124486200  133.061203
# 2020-12-29  134.385091  135.105436  130.773576  121047300  131.289505
# 2020-12-30  131.980681  132.379800  129.858547   96452100  130.170059
# 2020-12-31  130.520502  131.162985  128.223154   99116600  129.167404
# 2021-01-04  129.975330  130.062937  123.394792  143301900  125.974442
#
# Price      Target_Close
# Ticker
# Date
# 2020-12-28   131.289505
# 2020-12-29   130.170059
# 2020-12-30   129.167404
# 2020-12-31   125.974442
# 2021-01-04   127.531967

# %% [markdown]
# ## Train-Test Split
#
# The dataset is split into:
# - **Training set** – used to learn patterns
# - **Testing set** – used to evaluate performance
#
# We avoid shuffling because stock data is **time-dependent**.

# %%
X = data[['Open', 'High', 'Low', 'Volume']]
y = data['Target_Close']

print(X.shape, y.shape)
# Out:
# (1254, 4) (1254,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %% [markdown]
# ## Model Training
#
# We train a **Linear Regression** model to learn the relationship between market features and the closing price.
#
# Linear Regression is chosen because:
# - It is interpretable
# - It provides a strong baseline
# - It works well for short-term numeric prediction

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

y_pred[:5]
# Out:
# array([253.44488139, 256.7203445 , 258.40772446, 253.42949493,
#        251.1159096 ])

# %% [markdown]
# ## Model Evaluation
#
# We evaluate the model using:
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - R² Score
#
# These metrics help quantify prediction accuracy.

# %%
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 3.122228699036585
# Root Mean Squared Error: 4.546677448378566

# %% [markdown]
# ## Actual vs Predicted Closing Prices
#
# We visualize:
# - Actual closing prices
# - Model-predicted closing prices
#
# This comparison helps identify trends, errors, and overall model performance.

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label="Actual Close Price")
plt.plot(y_pred, label="Predicted Close Price")

plt.title("Actual vs Predicted Closing Prices")
plt.xlabel("Time")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()

# %% [markdown]
# ## Predicting the Next Day’s Closing Price
#
# Finally, we use the most recent available market data to predict the **next trading day's closing price**.
#
# This simulates a real-world short-term prediction scenario.

# %%
# Take last available data
latest_data = X.iloc[-1].values.reshape(1, -1)

next_day_prediction = model.predict(latest_data)

print("Predicted Next Day Closing Price:", next_day_prediction[0])
# Out:
# Predicted Next Day Closing Price: 271.3565892294604

# %% [markdown]
# ## Final Insights & Conclusion
#
# In this task, we successfully built a short-term stock price prediction model using historical market data. By leveraging features such as Open, High, Low, and Volume, the model learned meaningful patterns related to the next day’s closing price.
#
# The regression model demonstrated that price-based features (Open, High, Low) have a stronger influence on predicting the closing price compared to Volume alone. The comparison between actual and predicted closing prices shows that the model captures overall trends reasonably well, although minor deviations exist due to market volatility.
#
# This project highlights the practical challenges of time-series prediction in financial markets and reinforces the importance of feature selection, data preprocessing, and model evaluation. While the model performs adequately for short-term estimation, further improvements could be achieved using advanced models such as LSTM or incorporating technical indicators.
